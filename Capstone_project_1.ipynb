# %% [markdown]
# <h1 style="text-align:center">Applied Data Science Capstone Project</h1>

# %% [markdown]
# <h3 style="text-align:center">Part of the IBM Data Science Professional Certificate</h3>
# <h3 style="text-align:center">and Applied Data Science Specialization</h3>

# %%
#import libraries 
import numpy as np
import pandas as pd
print("Libraries imported")
# Out:
# Libraries imported

# %%
#print introductory statement
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
